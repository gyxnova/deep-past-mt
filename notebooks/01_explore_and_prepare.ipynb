# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
GITHUB_TOKEN = "YOUR_GITHUB_TOKEN_HERE"

# %%
# !git clone https://gyxnova:GITHUB_TOKEN@github.com/gyxnova/deep-past-mt.git
# Out:
# Cloning into 'deep-past-mt'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 12 (delta 0), reused 9 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (12/12), 13.53 KiB | 13.53 MiB/s, done.

# %%
# %cd deep-past-mt
# Out:
# /content/deep-past-mt/deep-past-mt/deep-past-mt/deep-past-mt

# %%
# !pip install -r requirements.txt

# %%
import zipfile
import os

# Path to the zip in your Drive
zip_path = "/content/drive/MyDrive/deep-past/data/deep-past-initiative-machine-translation.zip"

# Path where we will extract
extract_path = "/content/drive/MyDrive/deep-past/data/extracted"

os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Extraction completed!")
# Out:
# Extraction completed!

# %%
DATA_PATH = "/content/drive/MyDrive/deep-past/data/extracted"
os.listdir(DATA_PATH)
# Out:
# ['publications.csv',
#  'published_texts.csv',
#  'eBL_Dictionary.csv',
#  'Sentences_Oare_FirstWord_LinNum.csv',
#  'OA_Lexicon_eBL.csv',
#  'bibliography.csv',
#  'test.csv',
#  'resources.csv',
#  'sample_submission.csv',
#  'train.csv']

# %%
import pandas as pd

train_df = pd.read_csv(os.path.join(DATA_PATH, 'train.csv'))
test_df  = pd.read_csv(os.path.join(DATA_PATH, 'test.csv'))
pub_df   = pd.read_csv(os.path.join(DATA_PATH, 'publications.csv'))
lexi_df   = pd.read_csv(os.path.join(DATA_PATH, 'OA_Lexicon_eBL.csv'))
linnum_df   = pd.read_csv(os.path.join(DATA_PATH, 'Sentences_Oare_FirstWord_LinNum.csv'))
bib_df   = pd.read_csv(os.path.join(DATA_PATH, 'bibliography.csv'))
dict_df   = pd.read_csv(os.path.join(DATA_PATH, 'eBL_Dictionary.csv'))
publ_df   = pd.read_csv(os.path.join(DATA_PATH, 'published_texts.csv'))
res_df   = pd.read_csv(os.path.join(DATA_PATH, 'resources.csv'))
ss_df   = pd.read_csv(os.path.join(DATA_PATH, 'sample_submission.csv'))

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)
print("Publications shape:", pub_df.shape)
print("Lexicon shape:", lexi_df.shape)
print("linnum shape:", linnum_df.shape)
print("Bibliography shape:", bib_df.shape)
print("Dictionary shape:", dict_df.shape)
print("Published texts shape:", publ_df.shape)
print("Resources shape:", res_df.shape)
print("Sample submission shape:", ss_df.shape)
# Out:
# Train shape: (1561, 3)
# Test shape: (4, 5)
# Publications shape: (216602, 4)
# Lexicon shape: (39332, 9)
# linnum shape: (9782, 12)
# Bibliography shape: (878, 8)
# Dictionary shape: (19215, 3)
# Published texts shape: (7953, 19)
# Resources shape: (292, 16)
# Sample submission shape: (4, 2)

# %%
train_df.sample(5)
# Out:
#                                    oare_id  \
# 611   5e71c0aa-de0d-4c4f-b87a-aa9a58ea1f39
# 514   4eb23b20-e6ce-4c45-ac07-07d62a2ef0d0
# 1134  b579fd6a-35c8-4905-beb9-5606cc240867
# 249   277b9f27-719e-42f6-afdd-cdf74fc2310f
# 966   98cd1550-6086-46d3-a89a-e411575afca0
#
#                                         transliteration  \
# 611   KIŠIB lu-zi-na KIŠIB a-šur-DU₁₀ ša ḫu-bu-ul a-...
# 514   ma-na KÙ.KI … DUMU sà-aḫ-ru-da-nim … iš-tù ḫa-...
# 1134  KIŠIB ḫi-na-a KIŠIB i-ku-pí-a-šùr DUMU en-um-a...
# 249   a-na ir-ma-a-šur qí-bí-ma um-ma en-um-a-šur-ma...
# 966   um-me-a-nu šu-lá-ba-an ku-ku-lá-num MAŠKIM ša ...
#
#                                             translation
# 611   Seal of Luzina, seal of Aššur-ṭāb, of the debt...
# 514   ? minas of ... owed by ... son of Sahrudannum....
# 1134  Seal of hinnāya, seal of Ikuppi-Aššur, son of ...
# 249   Say to Ir'am-Aššur, thus Ennam-Aššur: When in ...
# 966   Šu-Laban's investors, Kukkulānum, the attorney...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1561 entries, 0 to 1560
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   oare_id          1561 non-null   object
#  1   transliteration  1561 non-null   object
#  2   translation      1561 non-null   object
# dtypes: object(3)
# memory usage: 36.7+ KB

# %%
train_df['transliteration'].str.len().describe()
# Out:
# count    1561.000000
# mean      426.459321
# std       269.688193
# min        21.000000
# 25%       204.000000
# 50%       365.000000
# 75%       632.000000
# max       932.000000
# Name: transliteration, dtype: float64

# %%
train_df['translation'].str.len().describe()
# Out:
# count    1561.000000
# mean      499.723895
# std       466.365112
# min         6.000000
# 25%       172.000000
# 50%       383.000000
# 75%       681.000000
# max      3895.000000
# Name: translation, dtype: float64

# %%
train_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
pub_df.sample(5)
# Out:
#                                                  pdf_name  page  \
# 190599  Veenhof, K. & Eidem, J. - Mesopotamia, The Old...   215
# 86095    Kawakami_2006_AlRafidan27_loc_Purushanta.PDF.pdf    10
# 152094  Renger, Johannes ed - Assur -- Gott, Stadt und...    47
# 13666   Barjamovic, Gojko - A Historical Geography of ...   112
# 11901                                      ATHE, 1960.pdf    13
#
#                                                 page_text  has_akkadian
# 190599  The Old Assyrian Period\nII and lb, and the tw...         False
# 86095   68\nNaohiko KAWAKAMI\norder to clear up the ma...         False
# 152094  34\nFriedhelm Pedde\nDIE PALASTGRUNDRISSE VOM ...         False
# 13666   4.1 HAHHUM\nPurushaddum (7 attestations, 3 'it...         False
# 11901   RECHTSURKUNDEN\nVERPFLICHTUNGSSCHEIN\nHülle, s...          True

# %%
pub_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216602 entries, 0 to 216601
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   pdf_name      216602 non-null  object
#  1   page          216602 non-null  int64
#  2   page_text     216602 non-null  object
#  3   has_akkadian  216602 non-null  bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 5.2+ MB

# %%
pub_df.duplicated().sum()
# Out:
# np.int64(108737)

# %%
pub_df.drop_duplicates(inplace=True)
pub_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
pub_df.shape
# Out:
# (107865, 4)

# %%
# linnum_df.sample(5)

# %%
# linnum_df.info()

# %%
# lexi_df.sample(5)

# %%
# lexi_df.info()

# %%
# bib_df.sample(5)

# %%
# bib_df.info()

# %%
# dict_df.sample(5)

# %%
# dict_df.info()

# %%
# res_df.sample(5)

# %%
# res_df.info()

# %%
# publ_df.sample(5)

# %%
# publ_df.info()

# %%
import pandas as pd
import re

subscript_map = str.maketrans("₀₁₂₃₄₅₆₇₈₉ₓ", "0123456789x")

VOWEL_MAP = {
    "á": "a2", "à": "a3",
    "é": "e2", "è": "e3",
    "í": "i2", "ì": "i3",
    "ú": "u2", "ù": "u3"
}

LETTER_MAP = {
    "Ḫ": "H", "ḫ": "h",
    "š": "sz", "Š": "SZ",
    "ṣ": "s", "Ṣ": "S",
    "ṭ": "t", "Ṭ": "T",
}

def clean_text(text):
    if pd.isna(text):
        return ""

    text = str(text)

    # Subscripts → normal
    text = text.translate(subscript_map)

        # vowels
    for k,v in VOWEL_MAP.items():
        text = text.replace(k,v)

    # consonants
    for k,v in LETTER_MAP.items():
        text = text.replace(k,v)

    # Remove line numbers like 1' 10''
    text = re.sub(r"\b\d+('{1,2})\b", "", text)


    # gaps
    text = re.sub(r"\[\s*\.{3}\s*\]", " <big_gap> ", text)
    text = re.sub(r"\[\s*x\s*\]", " <gap> ", text)
    text = text.replace("…", " <big_gap> ")

    # # protect gap tokens
    # text = text.replace("<gap>", " GAPTOKEN ")
    # text = text.replace("<big_gap>", " BIGGAPTOKEN ")

    # remove certainty + dividers
    text = re.sub(r"[!?/:]"," ",text)

    # remove half brackets
    text = text.replace("˹","").replace("˺","")

    # remove parentheses
    text = re.sub(r"\((.*?)\)","",text)

    # remove << >> and < >
    text = re.sub(r"<<(.*?)>>", r"\1", text)
    text = re.sub(r"<(?!big_gap|gap)(.*?)>", r"\1", text)

    # # restore gap tokens
    # text = text.replace("GAPTOKEN", "<gap>")
    # text = text.replace("BIGGAPTOKEN", "<big_gap>")

    # remove [] but keep inside
    text = re.sub(r"\[(.*?)\]",r"\1",text)

    # collapse spaces
    text = re.sub(r"\s+"," ",text).strip()

    return text

# %%
train_df["clean_transliteration"] = train_df["transliteration"].apply(clean_text)

# %%
train_df.sample(5)
# Out:
#                                    oare_id  \
# 1328  d6ace566-53f6-46a8-a94d-845856ce5a9a
# 702   6ec5d894-6733-4b4a-a99d-a32449ee1429
# 707   6fcd5786-adcb-4503-9e00-7bcbf97a2414
# 1130  b4fd7abc-12d2-4fde-8f30-c9310838216d
# 575   58bc835e-7132-47c4-9e23-ebd468c0ac6f
#
#                                         transliteration  \
# 1328  41 ma-na 11.5 GÍN KÙ.BABBAR ṣa-ru-pá-am ku-nu-...
# 702   lá-qé-ep DUMU šu-a-šùr a-dí-in a-ša-me-ma ma-á...
# 707   i-na 16.83333 ma-na ḫu-sà-ri-im ša ik-ri-bi ša...
# 1130  (large break) a-dí ša ta-áš-pu-ra-ni um-ma a-t...
# 575   um-ma PUZUR₄-a-na ù a-šur-ra-bi-ma a-na šu-be-...
#
#                                             translation  \
# 1328  41 minas 11.5 shekels of refined silver, seale...
# 702   ... I gave to Lā-qēp son of Šu-Aššur. I hear t...
# 707   Of the 16 ⅚ minas of lapis lazuli from the vot...
# 1130  ... Concerning what you wrote me, saying: 180 ...
# 575   Thus Puzur-Anna and Aššur-rabi, say to Šu-Bēlu...
#
# ...
